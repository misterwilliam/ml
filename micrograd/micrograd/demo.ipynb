# %%
import autodiff

# %%
a = autodiff.Value(1, label="a")
b = autodiff.Value(2, label="b")
c = autodiff.Value(4, label="c")
d = a + b; d.label = "d"
e = c * d; e.label = "e"
# 12 = 4 * (1 + 2)
e
# Out:
# Value(data=12.0)

# %%
e.backward()

# %%
autodiff.draw_dot(e)
